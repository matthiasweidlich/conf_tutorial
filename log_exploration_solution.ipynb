# %% [markdown]
# <a href="https://colab.research.google.com/github/matthiasweidlich/conf_tutorial/blob/master/log_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hands-On Exercise 1: Process Log Exploration
#
# In this exercise, you will get first insights into the structure of a real-life event log. We are going to use a log which was part of the Business Processing Intelligence Challenge 2012 (BPI Challenge 2012).
#
# **A few details about the scenario of the event log**
#
# The log originates from a Dutch Financial Institute. It contains some 262.200 events in 13.087 cases. Apart from some anonymization, the log contains all data as it came from the financial institute. The process represented in the event log is an application process for a personal loan or overdraft within a global financing organization. The amount requested by the customer is indicated in the case attribute AMOUNT_REQ, which is global, i.e. every case contains this attribute. The event log is a merger of three intertwined sub processes. The first letter of each task name identifies from which sub process (source) it originated from.
#
# In the process, an application is submitted through a webpage. Then, some automatic checks are performed, after which the application is complemented with additional information. This information is obtained trough contacting the customer by phone. If an applicant is eligible, an offer is sent to the client by mail. After this offer is received back, it is assessed. When it is incomplete, missing information is added by again contacting the customer. Then a final assessment is done, after which the application is approved and activated.
#
# **Event type explanation**
#
# | Event Type | Meaning |
# | --- | --- |
# | States starting with ‘A_’ | States of the application |
# | States starting with ‘O_’ |	States of the offer belonging to the application |
# | States starting with ‘W_’ |	States of the work item belonging to the application |
# COMPLETE |	The task (of type ‘A_’ or ‘O_’) is completed |
# SCHEDULE |	The work item (of type ‘W_’) is created in the queue (automatic step following manual actions)|
# START 	| The work item (of type ‘W_’) is obtained by the resource|
# COMPLETE |	The work item (of type ‘W_’) is released by the resource and put back in the queue or transferred to another queue (SCHEDULE)|
#
# **Event translation**
#
# | Dutch state name | 	English translation |
# | --- | --- |
# |W_Afhandelen leads |	W_Fixing incoming lead|
# |W_Completeren aanvraag  |	W_Filling in information for the application|
# |W_Valideren aanvraag |	W_Assessing the application|
# |W_Nabellen offertes 	| W_Calling after sent offers|
# |W_Nabellen incomplete dossiers |	W_Calling to add missing information to the application|
#
#
#
# You can download the event log (XES format, please unzip) [here](http://www.win.tue.nl/bpi/doku.php?id=2012:challenge).

# %%
# basic configuration
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Import Event Log
# The following method imports the log file and returns it in a list structure.

# %%
import xml.etree.ElementTree as et


def load_xes(file):
    log = []
    
    tree = et.parse(file)
    data = tree.getroot()
    
    # find all traces
    traces = data.findall('{http://www.xes-standard.org/}trace')
    
    for t in traces:
        trace_id = None
        
        # get trace id
        for a in t.findall('{http://www.xes-standard.org/}string'):
            if a.attrib['key'] == 'concept:name':
                trace_id = a.attrib['value']
        
        events = []
        # events
        for event in t.iter('{http://www.xes-standard.org/}event'):
            
            e = {'name': None, 'timestamp': None, 'resource': None, 'transition': None}
            
            for a in event:
                e[a.attrib['key'].split(':')[1]] = a.attrib['value']

            events.append(e)
        
        # add trace to log
        log.append({'trace_id': trace_id, 'events': events})
        
    return log

# %% [markdown]
# Now import the given log and inspect the first three traces.

# %%
from pprint import pprint

log_file = '//content/drive/My Drive/Colab Notebooks/tutorial/financial_log.xes'
log = load_xes(log_file)

print('Load log with %s traces.' %len(log))
pprint(log[:3])
# Out:
# Load log with 13087 traces.
# [{'events': [{'name': 'A_SUBMITTED',
#               'resource': '112',
#               'timestamp': '2011-10-01T00:38:44.546+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_PARTLYSUBMITTED',
#               'resource': '112',
#               'timestamp': '2011-10-01T00:38:44.880+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_PREACCEPTED',
#               'resource': '112',
#               'timestamp': '2011-10-01T00:39:37.906+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': '112',
#               'timestamp': '2011-10-01T00:39:38.875+02:00',
#               'transition': 'SCHEDULE'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': None,
#               'timestamp': '2011-10-01T11:36:46.437+02:00',
#               'transition': 'START'},
#              {'name': 'A_ACCEPTED',
#               'resource': '10862',
#               'timestamp': '2011-10-01T11:42:43.308+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_SELECTED',
#               'resource': '10862',
#               'timestamp': '2011-10-01T11:45:09.243+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_FINALIZED',
#               'resource': '10862',
#               'timestamp': '2011-10-01T11:45:09.243+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_CREATED',
#               'resource': '10862',
#               'timestamp': '2011-10-01T11:45:11.197+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_SENT',
#               'resource': '10862',
#               'timestamp': '2011-10-01T11:45:11.380+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-01T11:45:11.554+02:00',
#               'transition': 'SCHEDULE'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': None,
#               'timestamp': '2011-10-01T11:45:13.917+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-01T12:15:41.290+02:00',
#               'transition': 'START'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-01T12:17:08.924+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '10913',
#               'timestamp': '2011-10-08T16:26:57.720+02:00',
#               'transition': 'START'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '10913',
#               'timestamp': '2011-10-08T16:32:00.886+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11049',
#               'timestamp': '2011-10-10T11:32:22.495+02:00',
#               'transition': 'START'},
#              {'name': 'O_SENT_BACK',
#               'resource': '11049',
#               'timestamp': '2011-10-10T11:33:03.668+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Valideren aanvraag',
#               'resource': '11049',
#               'timestamp': '2011-10-10T11:33:04.560+02:00',
#               'transition': 'SCHEDULE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11049',
#               'timestamp': '2011-10-10T11:33:05.791+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Valideren aanvraag',
#               'resource': '10629',
#               'timestamp': '2011-10-13T10:05:26.925+02:00',
#               'transition': 'START'},
#              {'name': 'A_REGISTERED',
#               'resource': '10629',
#               'timestamp': '2011-10-13T10:37:29.226+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_APPROVED',
#               'resource': '10629',
#               'timestamp': '2011-10-13T10:37:29.226+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_ACCEPTED',
#               'resource': '10629',
#               'timestamp': '2011-10-13T10:37:29.226+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_ACTIVATED',
#               'resource': '10629',
#               'timestamp': '2011-10-13T10:37:29.226+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Valideren aanvraag',
#               'resource': '10629',
#               'timestamp': '2011-10-13T10:37:37.026+02:00',
#               'transition': 'COMPLETE'}],
#   'trace_id': '173688'},
#  {'events': [{'name': 'A_SUBMITTED',
#               'resource': '112',
#               'timestamp': '2011-10-01T08:08:58.256+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_PARTLYSUBMITTED',
#               'resource': '112',
#               'timestamp': '2011-10-01T08:09:02.195+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_PREACCEPTED',
#               'resource': '112',
#               'timestamp': '2011-10-01T08:09:56.648+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': '112',
#               'timestamp': '2011-10-01T08:09:59.578+02:00',
#               'transition': 'SCHEDULE'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': None,
#               'timestamp': '2011-10-01T11:37:32.393+02:00',
#               'transition': 'START'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': None,
#               'timestamp': '2011-10-01T11:43:13.178+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': None,
#               'timestamp': '2011-10-01T14:27:57.775+02:00',
#               'transition': 'START'},
#              {'name': 'A_ACCEPTED',
#               'resource': '10862',
#               'timestamp': '2011-10-01T14:33:54.614+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_FINALIZED',
#               'resource': '10862',
#               'timestamp': '2011-10-01T14:35:46.016+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_SELECTED',
#               'resource': '10862',
#               'timestamp': '2011-10-01T14:35:46.016+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_CREATED',
#               'resource': '10862',
#               'timestamp': '2011-10-01T14:35:47.488+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_SENT',
#               'resource': '10862',
#               'timestamp': '2011-10-01T14:35:47.583+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-01T14:35:47.682+02:00',
#               'transition': 'SCHEDULE'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': None,
#               'timestamp': '2011-10-01T14:35:48.791+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-01T14:36:13.443+02:00',
#               'transition': 'START'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-01T14:36:25.794+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-03T16:54:43.257+02:00',
#               'transition': 'START'},
#              {'name': 'O_SELECTED',
#               'resource': '11120',
#               'timestamp': '2011-10-03T16:56:17.731+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_CANCELLED',
#               'resource': '11120',
#               'timestamp': '2011-10-03T16:56:17.731+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_CREATED',
#               'resource': '11120',
#               'timestamp': '2011-10-03T16:56:19.613+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_SENT',
#               'resource': '11120',
#               'timestamp': '2011-10-03T16:56:19.645+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-03T16:56:19.941+02:00',
#               'transition': 'SCHEDULE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-03T16:56:21.195+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-03T16:56:34.792+02:00',
#               'transition': 'START'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-03T16:57:16.563+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11049',
#               'timestamp': '2011-10-10T10:13:44.827+02:00',
#               'transition': 'START'},
#              {'name': 'O_SENT_BACK',
#               'resource': '11049',
#               'timestamp': '2011-10-10T10:14:43.775+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Valideren aanvraag',
#               'resource': '11049',
#               'timestamp': '2011-10-10T10:14:44.052+02:00',
#               'transition': 'SCHEDULE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11049',
#               'timestamp': '2011-10-10T10:14:45.514+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Valideren aanvraag',
#               'resource': '10809',
#               'timestamp': '2011-10-10T11:12:36.612+02:00',
#               'transition': 'START'},
#              {'name': 'W_Valideren aanvraag',
#               'resource': '10809',
#               'timestamp': '2011-10-10T11:30:54.893+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Valideren aanvraag',
#               'resource': '10809',
#               'timestamp': '2011-10-10T14:11:42.124+02:00',
#               'transition': 'START'},
#              {'name': 'W_Valideren aanvraag',
#               'resource': '10809',
#               'timestamp': '2011-10-10T14:14:13.394+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Valideren aanvraag',
#               'resource': '10809',
#               'timestamp': '2011-10-10T14:14:52.842+02:00',
#               'transition': 'START'},
#              {'name': 'O_ACCEPTED',
#               'resource': '10809',
#               'timestamp': '2011-10-10T14:17:26.306+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_APPROVED',
#               'resource': '10809',
#               'timestamp': '2011-10-10T14:17:26.307+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_REGISTERED',
#               'resource': '10809',
#               'timestamp': '2011-10-10T14:17:26.307+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_ACTIVATED',
#               'resource': '10809',
#               'timestamp': '2011-10-10T14:17:26.307+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Valideren aanvraag',
#               'resource': '10809',
#               'timestamp': '2011-10-10T14:17:34.633+02:00',
#               'transition': 'COMPLETE'}],
#   'trace_id': '173691'},
#  {'events': [{'name': 'A_SUBMITTED',
#               'resource': '112',
#               'timestamp': '2011-10-01T08:10:30.287+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_PARTLYSUBMITTED',
#               'resource': '112',
#               'timestamp': '2011-10-01T08:10:30.591+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_PREACCEPTED',
#               'resource': '112',
#               'timestamp': '2011-10-01T08:11:13.026+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': '112',
#               'timestamp': '2011-10-01T08:11:13.390+02:00',
#               'transition': 'SCHEDULE'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': '10912',
#               'timestamp': '2011-10-01T11:31:25.301+02:00',
#               'transition': 'START'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': '10912',
#               'timestamp': '2011-10-01T11:35:59.637+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': None,
#               'timestamp': '2011-10-03T11:12:02.445+02:00',
#               'transition': 'START'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': None,
#               'timestamp': '2011-10-03T11:21:22.417+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:21:06.626+02:00',
#               'transition': 'START'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:32:43.313+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:32:52.818+02:00',
#               'transition': 'START'},
#              {'name': 'A_ACCEPTED',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:34:25.421+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_FINALIZED',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:40:14.632+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_SELECTED',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:40:14.632+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_CREATED',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:40:15.605+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_SENT',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:40:15.651+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:40:15.865+02:00',
#               'transition': 'SCHEDULE'},
#              {'name': 'W_Completeren aanvraag',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:40:17.062+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:40:42.469+02:00',
#               'transition': 'START'},
#              {'name': 'O_SELECTED',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:44:17.619+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_CANCELLED',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:44:17.619+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_CREATED',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:44:19.671+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_SENT',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:44:19.719+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:44:19.954+02:00',
#               'transition': 'SCHEDULE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11201',
#               'timestamp': '2011-10-03T13:44:21.261+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-10T16:46:59.853+02:00',
#               'transition': 'START'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-10T16:47:18.803+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11119',
#               'timestamp': '2011-10-10T19:29:54.155+02:00',
#               'transition': 'START'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11119',
#               'timestamp': '2011-10-10T19:34:36.027+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '10912',
#               'timestamp': '2011-10-14T18:15:44.625+02:00',
#               'transition': 'START'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '10912',
#               'timestamp': '2011-10-14T18:16:42.245+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '10861',
#               'timestamp': '2011-10-17T19:41:28.395+02:00',
#               'transition': 'START'},
#              {'name': 'O_SELECTED',
#               'resource': '10861',
#               'timestamp': '2011-10-17T19:43:53.587+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_CANCELLED',
#               'resource': '10861',
#               'timestamp': '2011-10-17T19:43:53.587+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_CREATED',
#               'resource': '10861',
#               'timestamp': '2011-10-17T19:43:55.219+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'O_SENT',
#               'resource': '10861',
#               'timestamp': '2011-10-17T19:43:55.387+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '10861',
#               'timestamp': '2011-10-17T19:43:56.402+02:00',
#               'transition': 'SCHEDULE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '10861',
#               'timestamp': '2011-10-17T19:43:57.774+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-25T10:46:08.191+02:00',
#               'transition': 'START'},
#              {'name': 'W_Nabellen offertes',
#               'resource': None,
#               'timestamp': '2011-10-25T10:50:48.186+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11203',
#               'timestamp': '2011-10-26T18:48:57.136+02:00',
#               'transition': 'START'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11203',
#               'timestamp': '2011-10-26T18:50:22.004+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11181',
#               'timestamp': '2011-10-29T12:39:08.212+02:00',
#               'transition': 'START'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11181',
#               'timestamp': '2011-10-29T12:41:29.569+02:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11189',
#               'timestamp': '2011-11-01T14:54:40.128+01:00',
#               'transition': 'START'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11189',
#               'timestamp': '2011-11-01T14:55:35.020+01:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11119',
#               'timestamp': '2011-11-01T17:16:31.149+01:00',
#               'transition': 'START'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11119',
#               'timestamp': '2011-11-01T17:21:02.356+01:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11049',
#               'timestamp': '2011-11-02T09:11:44.251+01:00',
#               'transition': 'START'},
#              {'name': 'O_SENT_BACK',
#               'resource': '11049',
#               'timestamp': '2011-11-02T09:15:16.203+01:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Valideren aanvraag',
#               'resource': '11049',
#               'timestamp': '2011-11-02T09:15:16.386+01:00',
#               'transition': 'SCHEDULE'},
#              {'name': 'W_Nabellen offertes',
#               'resource': '11049',
#               'timestamp': '2011-11-02T09:15:18.683+01:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Valideren aanvraag',
#               'resource': '10609',
#               'timestamp': '2011-11-04T15:24:21.954+01:00',
#               'transition': 'START'},
#              {'name': 'O_ACCEPTED',
#               'resource': '10609',
#               'timestamp': '2011-11-04T16:04:52.611+01:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_APPROVED',
#               'resource': '10609',
#               'timestamp': '2011-11-04T16:04:52.612+01:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_REGISTERED',
#               'resource': '10609',
#               'timestamp': '2011-11-04T16:04:52.612+01:00',
#               'transition': 'COMPLETE'},
#              {'name': 'A_ACTIVATED',
#               'resource': '10609',
#               'timestamp': '2011-11-04T16:04:52.612+01:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Valideren aanvraag',
#               'resource': '10609',
#               'timestamp': '2011-11-04T16:05:01.532+01:00',
#               'transition': 'COMPLETE'},
#              {'name': 'W_Wijzigen contractgegevens',
#               'resource': '10912',
#               'timestamp': '2012-02-15T12:29:26.299+01:00',
#               'transition': 'SCHEDULE'}],
#   'trace_id': '173694'}]

# %% [markdown]
# ## Section 1: Traces
# Each log contains at least one trace. Each trace again consists out of events. In the first section, you will inspect several trace properties, like trace length, trace variants and more.

# %% [markdown]
# ### Trace length
# A trace consists of events. The number of events in a trace defines its length. The code snippet below computes the length of the shortest and the longest trace in the log.

# %%
max_length = 0
min_length = 1000

for trace in log:
    if len(trace['events']) > max_length:
        max_length = len(trace['events'])
        
    if len(trace['events']) < min_length:
        min_length = len(trace['events'])

print('The longest trace contains %s events. The shortest trace: %s events.' %(max_length, min_length))
# Out:
# The longest trace contains 175 events. The shortest trace: 3 events.

# %% [markdown]
# **Task**: Compute the length of all traces in the log. Use a histogram to visualize your findings.

# %%
import matplotlib.pyplot as plt

trace_length = []

for trace in log:
    trace_length.append(len(trace['events']))
    

plt.hist(trace_length, bins=range(min_length, max_length, 5))
plt.xlabel('events per trace')
plt.ylabel('number of traces')
plt.show()

# %% [markdown]
# ### Trace variants
# A trace can be seen as a sequence of events. Since the same sequence of event classes may occur multiple times in the same log, it might be interesting to know how many different traces exist. Such different traces are called trace variants. The code snippet below computes all trace variants in the log:

# %%
trace_list = []

for trace in log:
    events = []
    for event in trace['events']:
        events.append(event['name'])
        
    trace_list.append(tuple(events))

trace_variants = set(trace_list)

print('The log contains %s trace variants.' %len(trace_variants))
# Out:
# The log contains 4366 trace variants.

# %% [markdown]
# ### Trace variant frequency
#
# **Task**: Compute the frequency of each trace variant in the log.

# %%
from collections import Counter
counter = [1]

counter = (Counter(trace_list).values())
#counter.sort(reverse=True)
#print(counter)
 
plt.hist(counter, bins=range(min(counter), max(counter)+100, 50))
plt.xlabel('traces of variant')
plt.ylabel('frequency')
plt.yscale('log')
plt.show()

# %% [markdown]
# **Task**: Which variant is the most frequent one?

# %%
Counter(trace_list).most_common()[0]
# Out:
# (('A_SUBMITTED', 'A_PARTLYSUBMITTED', 'A_DECLINED'), 3429)

# %% [markdown]
# ### Trace duration
# Events may have several attributes like a timestamp or a resource. We can use these timestamps to compute the duration of a single trace. The following code returns the shortest and longest duration of all traces in the log.

# %%
def get_timestamp(input_str: str):
    """
    Method to convert a string into a timestamp.
    
    :param input_str: timestamp as string
    """    
    timestamp_format = '%Y-%m-%dT%H:%M:%S.%f%z'
    
    return datetime.strptime(''.join(input_str.rsplit(':', 1)), timestamp_format)

# %%
from datetime import datetime, timedelta


max_duration = timedelta(microseconds=1)
min_duration = timedelta(days=10000)

for trace in log:
    
    # we only need to consider the first and last event in the trace
    first_e = trace['events'][0]
    last_e = trace['events'][-1]
    
    t0 = get_timestamp(first_e['timestamp'])
    t1 = get_timestamp(last_e['timestamp'])
    duration = t1 - t0
    
    if duration > max_duration:
        max_duration = duration
    elif duration < min_duration:
        min_duration = duration
        
print('The shortest process instance took %s; the longest %s' %(min_duration, max_duration))
# Out:
# The shortest process instance took 0:00:01.855000; the longest 137 days, 5:18:56.012000

# %% [markdown]
# **Task:** Compute the duration of each trace in seconds in the log and visualize the result in a histogram. *Hint*: use the method `total_seconds()`.

# %%
durations = []

for trace in log:
    first_e = trace['events'][0]
    last_e = trace['events'][-1]
    
    t0 = get_timestamp(first_e['timestamp'])
    t1 = get_timestamp(last_e['timestamp'])
    durations.append((t1 - t0).total_seconds())
    
plt.hist(durations, bins=range(0, round(max(durations)), 86400))
ax = plt.gca()
plt.xticks(rotation='vertical')
plt.xlabel('duration in seconds')
plt.ylabel('number of traces')
plt.show()

# %% [markdown]
# ### Trace start days
# We can use timestamps to get even more insights. For example, it might be interesting to know at which weekday the most process instances start.
#
# **Task:** How many different resources are used in a process instances?Extract for all traces the day of the week at which the instance was started. *Hint*: use `isoweekday()` to get the weekday of an datetime object.

# %%
import numpy as np

weekdays = []

for trace in log:
    first_e = trace['events'][0]
    t0 = get_timestamp(first_e['timestamp'])
    weekdays.append(t0.isoweekday())
    
data = np.bincount(weekdays)[1:]
x_ticks = range(0,7)
plt.bar(x_ticks, data)
ax = plt.gca()
ax.set_xticks(x_ticks)
ax.set_xticklabels(['Mon', 'Tue', 'Wed', 'Thu', 'Fir', 'Sat', 'Sun'])
plt.show()

# %% [markdown]
# ## Section 2: Events
# So far, you got some insights into the trace level of the event log. Now, we will have a closer look at the individual events.

# %% [markdown]
# ### Events in the log
# **Task**: Get the total number of events in the log.

# %%
event_counter = 0

for trace in log:
  event_counter += len(trace['events'])
    
print('The log contains %s events.' %event_counter)
# Out:
# The log contains 262200 events.

# %% [markdown]
# ### Event classes
# Events may refer to different lifecycle states of activity execution. For example, the execution of an activity *A* can be scheduled, started and finally be complete. Here, the lifecycle of executing activity *A* has three states. Each state transition in such a lifecycle of activity execution can be considered as a separate event class. For example, "an activity of name A being scheduled" and "an activity of name A being started" are then two separate event classes.
#
# **Task**: Get the number of event classes based on information about the executed activity and the lifecycle transition and print out their names.

# %%
event_classes = set()

for trace in log:
    for event in trace['events']:
        event_classes.add((event['name'], event['transition']))


print('The log contains %s event classes.' %len(event_classes))
pprint(event_classes)
# Out:
# The log contains 36 event classes.
# {('A_ACCEPTED', 'COMPLETE'),
#  ('A_ACTIVATED', 'COMPLETE'),
#  ('A_APPROVED', 'COMPLETE'),
#  ('A_CANCELLED', 'COMPLETE'),
#  ('A_DECLINED', 'COMPLETE'),
#  ('A_FINALIZED', 'COMPLETE'),
#  ('A_PARTLYSUBMITTED', 'COMPLETE'),
#  ('A_PREACCEPTED', 'COMPLETE'),
#  ('A_REGISTERED', 'COMPLETE'),
#  ('A_SUBMITTED', 'COMPLETE'),
#  ('O_ACCEPTED', 'COMPLETE'),
#  ('O_CANCELLED', 'COMPLETE'),
#  ('O_CREATED', 'COMPLETE'),
#  ('O_DECLINED', 'COMPLETE'),
#  ('O_SELECTED', 'COMPLETE'),
#  ('O_SENT', 'COMPLETE'),
#  ('O_SENT_BACK', 'COMPLETE'),
#  ('W_Afhandelen leads', 'COMPLETE'),
#  ('W_Afhandelen leads', 'SCHEDULE'),
#  ('W_Afhandelen leads', 'START'),
#  ('W_Beoordelen fraude', 'COMPLETE'),
#  ('W_Beoordelen fraude', 'SCHEDULE'),
#  ('W_Beoordelen fraude', 'START'),
#  ('W_Completeren aanvraag', 'COMPLETE'),
#  ('W_Completeren aanvraag', 'SCHEDULE'),
#  ('W_Completeren aanvraag', 'START'),
#  ('W_Nabellen incomplete dossiers', 'COMPLETE'),
#  ('W_Nabellen incomplete dossiers', 'SCHEDULE'),
#  ('W_Nabellen incomplete dossiers', 'START'),
#  ('W_Nabellen offertes', 'COMPLETE'),
#  ('W_Nabellen offertes', 'SCHEDULE'),
#  ('W_Nabellen offertes', 'START'),
#  ('W_Valideren aanvraag', 'COMPLETE'),
#  ('W_Valideren aanvraag', 'SCHEDULE'),
#  ('W_Valideren aanvraag', 'START'),
#  ('W_Wijzigen contractgegevens', 'SCHEDULE')}

# %% [markdown]
# ### Event schedule
# We already computed how many process instances started at which day of the week. We can do the same for each event class.
#
# **Task:** Use the code snippet below as a starting point. *Hint:* use the methods `get_timestamp()` and `isoweekday()`.

# %%
# setup subplots
fig, ax = plt.subplots(12, 3, figsize=(12, 25))
fig.subplots_adjust(hspace = 2, wspace=0.3)
ax = ax.flatten()

for idx, target_event in enumerate(list(event_classes)):
    weekdays = []
    
    for trace in log:
        for event in trace['events']:
            if event['name'] == target_event[0] and event['transition'] == target_event[1]:
                t0 = get_timestamp(event['timestamp'])
                weekdays.append(t0.isoweekday())

    
    # plot
    data = np.bincount(weekdays)[1:]
    
    x_ticks = range(0,len(data), 1)
    ax[idx].bar(x_ticks, data)
    ax[idx].set_xticks(x_ticks)
    ax[idx].set_xticklabels(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'], rotation=45)
    ax[idx].set_title(target_event[0] + ' ' + target_event[1])
    
plt.show()

# %% [markdown]
# ### Event resource assignments
# Sometimes an event is processed by a resource. Possible resources are machines and employees. The used resource can be specified in the events attributes.
#
# **Task:** How many different resources are used in a process instances?

# %%
resources = []

for trace in log:
    for event in trace['events']:
        resources.append(event['resource'])

print('All process instances use %s different resource in total' % len(set(resources)))
# Out:
# All process instances use 18010 different resource in total

# %% [markdown]
# **Task**: Are all events processed by a resource? If not, compute the ratio of events that are processed by a resource.

# %%
no_res = resources.count(None)

print('%.2f%% of all events are processed by a resource.' %(((len(resources)-no_res)/len(resources))*100 ))
# Out:
# 93.13% of all events are processed by a resource.

# %% [markdown]
# ## -- End
